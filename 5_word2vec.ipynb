# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data. Word2vec is an efficient predictive model that directly predicts a word from context (the word' neighbors) in terms of learning small embedding vectors that represent that word. Word2vec has two variations: the skip-gram model predicts the neighbor words from the target words and the continuous bag-of-words model (CBOW) that predicts the word (e.g. 'coffee') from context ('I start each day with a cup of').

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
print(words[:10])
# Out:
# Data size 17005207
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
    
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.422637
# Nearest to or: capoeiristas, wharf, iterate, bliss, satisfiability, chromatin, vatican, md,
# Nearest to most: helmholtz, allahabad, oddly, lcds, opencyc, achievements, botswana, eastwards,
# Nearest to called: unanimously, benghazi, fountain, significance, smoot, unconcerned, sunga, hemispheric,
# Nearest to other: cotangent, salamander, tights, breakaway, scrape, dialectical, migrating, absentia,
# Nearest to if: alexandrina, dnow, sammy, adolphus, dogmas, sven, unnatural, natured,
# Nearest to at: rosen, gratis, schneider, jorge, rhombic, mahayana, amistad, lucia,
# Nearest to years: logograms, presocratic, zombie, countess, amendment, coarse, bodied, oliver,
# Nearest to used: martha, diametrically, trophy, bregovi, compulsive, gotovina, wilhelm, arndt,
# Nearest to american: abeda, eventual, waters, littoral, remarkable, sitting, gladly, papyri,
# Nearest to three: midline, vendetta, celled, apprehended, turnips, waxes, backtracking, sefirot,
# Nearest to people: shamash, danio, newport, weights, jute, warwick, parishes, slippery,
# Nearest to than: genesee, kart, steeply, bakunin, violation, installation, moldovan, basques,
# Nearest to he: za, arched, dread, audi, inputs, convened, ventilated, opined,
# Nearest to when: earthworm, inns, translators, cegep, ritz, freising, thousands, euroscepticism,
# Nearest to of: style, coerced, competitors, schafer, hamster, factum, wreckin, tully,
# Nearest to a: support, falsification, bluffs, impedes, releases, weldon, nacional, translational,
# Average loss at step 2000: 4.359671
# Average loss at step 4000: 3.870129
# Average loss at step 6000: 3.793683
# Average loss at step 8000: 3.690235
# Average loss at step 10000: 3.613627
# Nearest to or: and, than, pri, with, openoffice, talmudic, zhukov, milli,
# Nearest to most: oddly, scholar, eastwards, lcds, jordanian, suharto, phosphors, cas,
# Nearest to called: gow, alternated, unanimously, benghazi, balochistan, solar, soliciting, calculated,
# Nearest to other: salamander, ziv, tights, steinberg, jameson, correspondence, ratio, migrating,
# Nearest to if: flemish, sammy, rossetti, socially, cabinet, thy, moynihan, azimuth,
# Nearest to at: in, atrocity, infects, for, lucia, of, over, teleport,
# Nearest to years: logograms, zombie, presocratic, coarse, heh, countess, bodied, mullet,
# Nearest to used: diametrically, found, czar, captivity, polskiej, endlessly, brim, considered,
# Nearest to american: and, persians, remarkable, earlier, navy, perpendicular, sitting, birger,
# Nearest to three: six, seven, four, eight, five, two, nine, zero,
# Nearest to people: walkway, slippery, shamash, scrabble, danio, covered, italo, contained,
# Nearest to than: or, willfully, bakunin, genesee, rebellion, ontogeny, subfields, pune,
# Nearest to he: it, they, she, who, customers, blaze, pyrotechnics, polyethylene,
# Nearest to when: earthworm, priority, crusade, freising, secretes, thousands, confident, because,
# Nearest to of: in, at, oyster, compel, for, and, on, dysentery,
# Nearest to a: the, this, impedes, recessions, thibetanus, soles, raman, shan,
# Average loss at step 12000: 3.600587
# Average loss at step 14000: 3.568634
# Average loss at step 16000: 3.406506
# Average loss at step 18000: 3.456099
# Average loss at step 20000: 3.535268
# Nearest to or: than, and, introducing, pasiphae, pollen, renounced, crossovers, with,
# Nearest to most: more, eastwards, oddly, allahabad, many, lineages, all, very,
# Nearest to called: gow, ishaq, unanimously, albertus, ethiopians, known, calculated, alternated,
# Nearest to other: many, different, some, briefing, ziv, ratio, alen, jameson,
# Nearest to if: rossetti, flemish, but, devonian, pursuant, though, socially, sammy,
# Nearest to at: in, on, infects, from, for, atrocity, between, apparently,
# Nearest to years: zombie, days, logograms, unsolvable, presocratic, coarse, census, quicktime,
# Nearest to used: found, diametrically, known, considered, read, polskiej, monopoly, killed,
# Nearest to american: australian, british, remarkable, northrop, english, french, presumably, sitting,
# Nearest to three: four, five, six, two, seven, eight, zero, one,
# Nearest to people: slippery, shamash, scrabble, walkway, tasked, mobilization, satrap, covered,
# Nearest to than: or, genesee, bakunin, alamein, bashing, ontogeny, rebellion, stalinist,
# Nearest to he: it, they, she, who, there, we, drastically, flirted,
# Nearest to when: because, was, while, where, hence, earthworm, crusade, hover,
# Nearest to of: for, oyster, berthe, main, in, progeny, ged, rafter,
# Nearest to a: bahadur, the, this, recessions, impedes, milling, capone, topics,
# Average loss at step 22000: 3.502178
# Average loss at step 24000: 3.495142
# Average loss at step 26000: 3.479392
# Average loss at step 28000: 3.481042
# Average loss at step 30000: 3.501025
# Nearest to or: and, than, but, talmudic, brainiac, confessional, heightened, afield,
# Nearest to most: more, many, some, use, solvents, allahabad, phosphors, oddly,
# Nearest to called: albertus, milius, ishaq, island, known, nuances, gow, unanimously,
# Nearest to other: different, many, various, some, these, yarn, steinberg, ratio,
# Nearest to if: when, rossetti, flemish, though, but, where, would, since,
# Nearest to at: in, flanks, on, mossad, whilst, chu, apparently, after,
# Nearest to years: days, zombie, unsolvable, quicktime, census, advert, weeks, dormant,
# Nearest to used: known, found, written, considered, mentioned, parodying, diametrically, read,
# Nearest to american: british, australian, french, canadian, english, sitting, extremity, birger,
# Nearest to three: five, four, two, eight, seven, six, nine, zero,
# Nearest to people: slippery, americans, satrap, mobilization, tasked, facets, walkway, nanometers,
# Nearest to than: or, bashing, carbamazepine, genesee, bakunin, psychiatrists, penfield, alamein,
# Nearest to he: it, she, they, who, there, never, firearm, ls,
# Nearest to when: if, because, where, while, but, after, before, was,
# Nearest to of: berthe, in, ged, and, jewish, from, incongruous, early,
# Nearest to a: any, topics, recessions, the, liszt, soles, impedes, capone,
# Average loss at step 32000: 3.499140
# Average loss at step 34000: 3.490796
# Average loss at step 36000: 3.457253
# Average loss at step 38000: 3.307387
# Average loss at step 40000: 3.428176
# Nearest to or: and, than, beckham, samoan, embassy, antoninianus, negativity, tewahedo,
# Nearest to most: more, many, some, solvents, less, smashed, oddly, protagoras,
# Nearest to called: unanimously, albertus, ishaq, milius, tumors, imperialism, nuances, considered,
# Nearest to other: different, nellis, various, many, ratio, some, endangered, salamander,
# Nearest to if: when, where, rossetti, though, exiles, frankenchrist, is, nephropathy,
# Nearest to at: on, in, during, infects, for, chu, whilst, affording,
# Nearest to years: days, weeks, zombie, year, months, unsolvable, dormant, geographer,
# Nearest to used: known, found, considered, available, cited, referred, preserved, written,
# Nearest to american: british, australian, french, english, japanese, slot, italian, canadian,
# Nearest to three: five, four, two, seven, six, eight, nine, zero,
# Nearest to people: those, tribes, tasked, facets, men, satrap, avengers, americans,
# Nearest to than: or, much, bashing, penfield, bakunin, inform, willfully, psychiatrists,
# Nearest to he: she, it, they, who, there, then, eventually, flirted,
# Nearest to when: if, while, before, where, because, for, vikrant, after,
# Nearest to of: in, for, honeywell, allergies, berthe, original, forecasts, from,
# Nearest to a: the, soles, any, no, assures, drip, concerti, impedes,
# Average loss at step 42000: 3.432759
# Average loss at step 44000: 3.450980
# Average loss at step 46000: 3.451206
# Average loss at step 48000: 3.350260
# Average loss at step 50000: 3.379777
# Nearest to or: and, than, confessional, armament, scrolling, though, unmistakable, heist,
# Nearest to most: more, less, use, many, some, smashed, solvents, highly,
# Nearest to called: ishaq, albertus, known, unanimously, termed, alboin, referred, milius,
# Nearest to other: different, various, nellis, many, ratio, these, some, liberalization,
# Nearest to if: when, where, though, rossetti, although, before, frankenchrist, since,
# Nearest to at: during, affording, on, in, deseret, chu, overflowing, from,
# Nearest to years: days, weeks, zombie, year, unsolvable, months, dormant, presocratic,
# Nearest to used: known, found, written, available, seen, considered, referred, regarded,
# Nearest to american: australian, english, british, french, italian, irish, scottish, larvae,
# Nearest to three: four, eight, six, seven, five, nine, two, zero,
# Nearest to people: men, children, satrap, cenotaph, facets, others, avengers, jews,
# Nearest to than: penfield, much, or, bashing, carbamazepine, hashimoto, psychiatrists, pip,
# Nearest to he: it, she, they, there, who, then, eventually, this,
# Nearest to when: while, if, before, after, where, though, but, because,
# Nearest to of: in, including, welcomes, and, allergies, crossover, ged, permanent,
# Nearest to a: recessions, the, impedes, chimney, assures, any, no, another,
# Average loss at step 52000: 3.434035
# Average loss at step 54000: 3.425607
# Average loss at step 56000: 3.437865
# Average loss at step 58000: 3.399613
# Average loss at step 60000: 3.389836
# Nearest to or: and, than, borland, nolan, but, bottled, crossovers, bu,
# Nearest to most: more, many, use, some, less, smashed, summer, branches,
# Nearest to called: ishaq, referred, used, known, alboin, albertus, tumors, gabonese,
# Nearest to other: different, various, many, including, nellis, yarn, salamander, these,
# Nearest to if: when, where, though, since, before, rossetti, although, could,
# Nearest to at: during, in, apparently, affording, spivak, chu, infects, sdlp,
# Nearest to years: days, weeks, year, months, minutes, decades, bc, zombie,
# Nearest to used: known, written, found, available, held, seen, cited, employed,
# Nearest to american: australian, british, english, italian, french, indian, irish, european,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to people: men, those, children, satrap, others, socony, scientists, americans,
# Nearest to than: or, much, penfield, inform, stalinist, and, slow, sunnis,
# Nearest to he: she, it, they, there, who, flirted, eventually, i,
# Nearest to when: if, while, before, although, though, after, during, because,
# Nearest to of: in, ged, for, salads, including, belushi, same, and,
# Nearest to a: any, the, another, impedes, recessions, borneo, assures, this,
# Average loss at step 62000: 3.244874
# Average loss at step 64000: 3.249464
# Average loss at step 66000: 3.400080
# Average loss at step 68000: 3.396127
# Average loss at step 70000: 3.357756
# Nearest to or: and, than, distinctly, any, confessional, while, the, when,
# Nearest to most: more, less, some, many, use, summer, highly, throughout,
# Nearest to called: referred, known, tumors, alboin, termed, cited, gabonese, ishaq,
# Nearest to other: different, various, many, some, older, others, nellis, adhesives,
# Nearest to if: when, though, where, before, rossetti, since, could, while,
# Nearest to at: during, apparently, spivak, infects, around, chu, after, essentially,
# Nearest to years: days, weeks, months, year, minutes, decades, bc, centuries,
# Nearest to used: known, found, available, written, seen, responsible, described, employed,
# Nearest to american: british, italian, australian, english, international, canadian, intrinsic, irish,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to people: men, children, americans, those, others, students, members, scientists,
# Nearest to than: penfield, or, much, bashing, inform, profess, but, carbamazepine,
# Nearest to he: she, it, they, there, drastically, we, who, then,
# Nearest to when: if, while, before, where, because, though, however, after,
# Nearest to of: including, murad, include, and, ged, morin, ama, in,
# Nearest to a: the, another, recessions, assures, any, chickasaw, chimney, spiked,
# Average loss at step 72000: 3.375982
# Average loss at step 74000: 3.347105
# Average loss at step 76000: 3.310341
# Average loss at step 78000: 3.351762
# Average loss at step 80000: 3.378946
# Nearest to or: and, than, while, exporters, but, judson, poodle, confessional,
# Nearest to most: more, less, many, some, summer, throughout, among, especially,
# Nearest to called: referred, tumors, known, ishaq, considered, termed, used, alboin,
# Nearest to other: various, different, guanine, others, many, liberalization, nellis, canonical,
# Nearest to if: when, though, where, before, although, rossetti, until, then,
# Nearest to at: in, on, during, apparently, sdlp, around, chu, infects,
# Nearest to years: days, weeks, months, decades, minutes, year, centuries, bc,
# Nearest to used: known, available, written, seen, responsible, referred, found, cited,
# Nearest to american: british, australian, indian, italian, irish, scottish, french, canadian,
# Nearest to three: six, five, four, seven, two, eight, nine, zero,
# Nearest to people: men, children, students, americans, women, those, others, someone,
# Nearest to than: or, much, penfield, bashing, cheaper, kio, inform, carbamazepine,
# Nearest to he: she, it, they, there, who, we, never, fk,
# Nearest to when: if, before, while, after, though, where, during, although,
# Nearest to of: in, including, alcmene, daimyo, although, original, benito, foremost,
# Nearest to a: another, recessions, the, liszt, impedes, borneo, chimney, que,
# Average loss at step 82000: 3.409147
# Average loss at step 84000: 3.409493
# Average loss at step 86000: 3.388412
# Average loss at step 88000: 3.350290
# Average loss at step 90000: 3.364509
# Nearest to or: and, than, fullerene, nolan, though, lz, encoders, while,
# Nearest to most: more, less, many, some, summer, among, use, throughout,
# Nearest to called: referred, known, considered, used, termed, named, alboin, ishaq,
# Nearest to other: various, different, obvious, endangered, including, benefactors, liberalization, bujold,
# Nearest to if: when, though, where, since, although, rossetti, before, until,
# Nearest to at: during, near, around, affording, chu, in, sata, ducati,
# Nearest to years: days, weeks, minutes, months, decades, year, hours, centuries,
# Nearest to used: known, referred, seen, available, cited, found, required, employed,
# Nearest to american: british, italian, australian, indian, irish, french, scottish, african,
# Nearest to three: four, five, eight, two, seven, six, nine, zero,
# Nearest to people: men, children, students, americans, women, god, those, players,
# Nearest to than: much, penfield, or, inform, nov, somewhat, stratigraphy, elective,
# Nearest to he: she, they, it, there, who, later, never, we,
# Nearest to when: while, if, before, though, where, after, although, because,
# Nearest to of: including, and, in, morin, veiled, include, dawkins, alcmene,
# Nearest to a: recessions, the, any, contraband, impedes, liszt, every, soles,
# Average loss at step 92000: 3.394753
# Average loss at step 94000: 3.259539
# Average loss at step 96000: 3.358413
# Average loss at step 98000: 3.242811
# Average loss at step 100000: 3.351652
# Nearest to or: and, than, while, gisela, nottingham, angolan, confessional, exporters,
# Nearest to most: more, less, especially, throughout, some, many, among, all,
# Nearest to called: referred, named, used, termed, considered, known, spartacus, ishaq,
# Nearest to other: various, different, bujold, endangered, individual, others, specific, captives,
# Nearest to if: when, where, though, while, before, whether, although, since,
# Nearest to at: during, on, deseret, after, infects, whilst, benthic, under,
# Nearest to years: days, year, weeks, minutes, months, decades, centuries, hours,
# Nearest to used: available, designed, known, found, seen, referred, written, required,
# Nearest to american: british, italian, australian, irish, scottish, indian, canadian, international,
# Nearest to three: four, five, seven, two, six, eight, nine, zero,
# Nearest to people: men, students, children, americans, players, tribes, women, those,
# Nearest to than: or, much, penfield, bashing, considerably, promiscuity, psychiatrists, inform,
# Nearest to he: she, it, they, there, who, we, never, eventually,
# Nearest to when: while, if, although, before, where, though, during, after,
# Nearest to of: including, erasmus, in, welling, and, ces, sukarnoputri, nssdc,
# Nearest to a: another, the, recessions, any, jal, concerti, borneo, shan,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# CBOW model
# predict a word from the sum of all the word vectors in its context
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# batch : [['anarchism', 'as'], ['originated', 'a'], ['as', term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first']]
# labels: ['originated', 'as', 'a', 'term', 'of', 'abuse']

words = read_data(filename)
print('Data size %d' % len(words))
print(words[:10])

# vocabulary_size = 50000

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Data size 17005207
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
from itertools import compress

data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  # span = 3
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  # batch_size = 8
  # num_skips = 2
  # skip_window = 1
  # data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
  # batch: [['anarchism', 'as'], ['originated','a'],['as','term'], ['a','of'], ['term','abuse'],['of','first']]
  # labels: ['originated','as','a','term','of','abuse']

  # num_skips = 4
  # skip_window = 2
  # batch: [['anarchism', 'originated','a','term'], ['originated','as', 'term', 'of']]
  # labels: ['as','a', 'term', 'of']

  for i in range(batch_size ):
    mask = [1] * span
    target = skip_window  # target label at the center of the buffer
    mask[target] = 0
    labels[i,0] = buffer[target]
    batch[i,:] = list(compress(buffer, mask))
    buffer.append(data[data_index])  
#     print('buffer  :', [reverse_dictionary[bi] for bi in buffer])
    data_index = (data_index + 1) % len(data)
#     print("batch data shape: {}".format(batch.shape))
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8-2*skip_window, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(num_skips * (8-2*skip_window) )])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8-2*skip_window)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term', 'originated', 'as', 'term', 'of', 'as', 'a', 'of', 'abuse', 'a', 'term', 'abuse', 'first']
#     labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# Train a CBOW model.

# %%
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

batch_size = 128 - 2*skip_window
embedding_size = 128 - 2*skip_window # Dimension of the embedding vector.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
    
  print("train data shape: {}".format(train_dataset))

  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
    
  embed = tf.zeros([batch_size, embedding_size])
  for i in range(num_skips):
      embed += tf.nn.embedding_lookup(embeddings, train_dataset[:,i])

# Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# train data shape: Tensor("Placeholder:0", shape=(126, 2), dtype=int32, device=/device:CPU:0)

# %%
num_steps = 100001
# num_steps = 1
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):    
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window) 
    
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.396968
# Nearest to this: tamil, redeveloped, jfk, deployable, sae, difficulty, jointly, mexicans,
# Nearest to six: macrinus, telegrams, dat, hawaiian, ellery, frideric, longbow, ddd,
# Nearest to into: ej, narayan, backup, biggest, conservation, vieux, stagnant, ready,
# Nearest to not: chera, blocking, ninlil, manuscripts, mjt, toni, boiling, onyx,
# Nearest to world: attacks, reeves, curtain, iteration, nadh, transceiver, hexameter, mauser,
# Nearest to see: outcasts, reminded, immigrants, vizier, complete, litigants, courtney, properly,
# Nearest to or: inquisitions, apartment, mundi, leonov, wavelet, lambda, traffic, rouse,
# Nearest to s: gwp, cnd, enzymatic, borrowings, odense, caricatures, novel, rolls,
# Nearest to can: citizenry, palaestina, estate, rumour, nurturing, kill, collated, ateneo,
# Nearest to used: dancehall, thiele, distributist, wynne, whimsical, spline, observatory, pendants,
# Nearest to were: edgar, migrated, savonarola, utamaro, zechariah, strunk, battleships, krak,
# Nearest to nine: interventions, multiparty, edible, batmobile, blossomed, ambushes, pervading, cnet,
# Nearest to if: scolded, seditious, remit, immigrate, fer, vil, cooh, manifesto,
# Nearest to on: quatre, mummified, fractional, incarnations, watcher, schl, publica, snooker,
# Nearest to been: persisted, pillow, dinneen, chairmanship, ogilvie, ventris, nicaraguan, disfavor,
# Nearest to he: cimmerian, alef, subversion, riemann, slapped, selig, rallying, neutrons,
# Average loss at step 2000: 4.102248
# Average loss at step 4000: 3.572389
# Average loss at step 6000: 3.373559
# Average loss at step 8000: 3.255334
# Average loss at step 10000: 3.185099
# Nearest to this: it, which, the, heron, his, palgrave, a, another,
# Nearest to six: eight, seven, nine, five, four, three, one, two,
# Nearest to into: from, stagnant, towering, cs, biggest, narayan, redacted, in,
# Nearest to not: also, poking, onyx, shoals, generally, mainly, lesbos, often,
# Nearest to world: barricade, miko, harem, attacks, rcn, jamil, reeves, emulsion,
# Nearest to see: numeration, neustadt, stampede, trill, hetzel, but, cheats, lutheranism,
# Nearest to or: and, than, justice, prejudiced, but, cf, whatever, cottage,
# Nearest to s: zel, nongovernmental, his, aloe, fake, delta, smiley, transfinite,
# Nearest to can: may, would, could, must, will, should, might, deeper,
# Nearest to used: collaborate, distributist, dancehall, whimsical, regarded, envisioned, cellini, rhode,
# Nearest to were: are, was, had, been, nucleosynthesis, saucer, have, be,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to if: remit, when, seditious, visually, ubangi, pair, scolded, heritage,
# Nearest to on: in, upon, at, incarnations, against, succeeding, salieri, schleswig,
# Nearest to been: were, was, be, waring, tremolo, jaguars, hangs, dinneen,
# Nearest to he: she, it, they, who, panzer, delicious, there, sexy,
# Average loss at step 12000: 3.189879
# Average loss at step 14000: 3.157357
# Average loss at step 16000: 3.155931
# Average loss at step 18000: 3.125268
# Average loss at step 20000: 2.988748
# Nearest to this: it, which, that, another, heron, antisense, doren, orderly,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to into: from, through, back, sexy, biggest, propelling, around, backup,
# Nearest to not: often, t, generally, always, also, they, lesbos, poking,
# Nearest to world: vietnam, harem, barricade, outages, miko, deshima, vaishnavism, believing,
# Nearest to see: winn, but, concludes, known, opposes, stampede, trill, lutheranism,
# Nearest to or: and, than, bundaberg, birthdate, reassured, tapering, mashed, airbases,
# Nearest to s: zel, his, dentist, bromide, essendon, superluminal, whose, philologists,
# Nearest to can: will, may, could, would, must, might, should, cannot,
# Nearest to used: seen, regarded, available, found, spoken, known, written, considered,
# Nearest to were: are, was, have, had, suse, poisoning, been, nucleosynthesis,
# Nearest to nine: eight, seven, six, four, zero, five, three, one,
# Nearest to if: when, where, seditious, remit, injector, promenade, actinidia, ambients,
# Nearest to on: upon, in, at, succeeding, atat, celibate, weighting, about,
# Nearest to been: become, be, was, were, suzy, jaguars, hypocrisy, waring,
# Nearest to he: she, it, they, who, there, panzer, portrayals, delicious,
# Average loss at step 22000: 3.073546
# Average loss at step 24000: 3.066871
# Average loss at step 26000: 2.982339
# Average loss at step 28000: 3.039740
# Average loss at step 30000: 3.005519
# Nearest to this: it, which, that, what, the, antisense, graceland, heron,
# Nearest to six: eight, four, five, seven, nine, three, two, zero,
# Nearest to into: through, from, around, back, within, redacted, over, across,
# Nearest to not: still, t, onyx, always, usually, now, also, never,
# Nearest to world: vietnam, miko, deshima, harem, mauser, sexism, barricade, fallopian,
# Nearest to see: matthews, winn, called, but, concludes, larps, opengl, include,
# Nearest to or: and, than, cf, itanium, but, slavonic, arleigh, feasts,
# Nearest to s: whose, panacea, zel, airing, thabit, lambeau, his, warranted,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to used: known, seen, found, written, called, available, considered, regarded,
# Nearest to were: are, have, was, been, had, poisoning, being, confess,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to if: when, though, where, pimlico, exe, symbiotic, excite, nativist,
# Nearest to on: upon, in, about, through, at, anastasia, usc, until,
# Nearest to been: become, be, were, was, jaguars, bananas, hypocrisy, nasional,
# Nearest to he: she, it, they, there, who, panzer, i, fahd,
# Average loss at step 32000: 2.914516
# Average loss at step 34000: 2.861723
# Average loss at step 36000: 2.945595
# Average loss at step 38000: 2.951791
# Average loss at step 40000: 2.919545
# Nearest to this: which, it, the, another, what, some, orderly, heron,
# Nearest to six: seven, five, eight, four, nine, three, two, zero,
# Nearest to into: through, from, across, within, around, back, vilayet, andrzej,
# Nearest to not: still, generally, now, also, usually, onyx, almost, always,
# Nearest to world: vietnam, deshima, barricade, albans, internet, miko, fallopian, jamil,
# Nearest to see: winn, matthews, include, concludes, opengl, velvet, annoyance, surges,
# Nearest to or: and, than, crewe, birthdate, bundaberg, kitty, inscribed, cf,
# Nearest to s: whose, his, bromide, dumbarton, zel, lepidoptera, essendon, aloe,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to used: known, seen, referred, found, available, considered, regarded, written,
# Nearest to were: are, have, was, had, been, when, be, cranberries,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to if: when, though, then, where, before, so, quantitatively, since,
# Nearest to on: upon, in, through, celibate, at, mitsubishi, about, theropod,
# Nearest to been: become, be, was, were, grown, jaguars, introns, hypocrisy,
# Nearest to he: she, it, they, there, who, we, alem, bitterly,
# Average loss at step 42000: 2.935788
# Average loss at step 44000: 2.979344
# Average loss at step 46000: 2.919608
# Average loss at step 48000: 2.920402
# Average loss at step 50000: 2.845908
# Nearest to this: it, which, the, another, what, some, heron, palgrave,
# Nearest to six: seven, eight, five, nine, four, three, zero, one,
# Nearest to into: through, from, back, around, within, obliquely, across, racecourse,
# Nearest to not: still, never, mainly, now, onyx, actually, you, generally,
# Nearest to world: vietnam, deshima, barricade, jamil, miko, u, season, progesterone,
# Nearest to see: matthews, include, winn, refer, hada, karenga, links, coulter,
# Nearest to or: and, than, while, but, feasts, arleigh, though, non,
# Nearest to s: whose, zel, isbn, your, brisingamen, essendon, delta, dentist,
# Nearest to can: may, could, will, must, would, should, might, cannot,
# Nearest to used: known, referred, seen, available, found, written, designed, sold,
# Nearest to were: are, was, have, had, be, phocas, been, while,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to if: when, though, where, before, then, excite, pimlico, protectors,
# Nearest to on: upon, succeeding, through, regarding, xm, in, rotates, about,
# Nearest to been: become, be, was, grown, recently, already, jaguars, were,
# Nearest to he: she, it, they, there, who, we, panzer, russell,
# Average loss at step 52000: 2.846265
# Average loss at step 54000: 2.864364
# Average loss at step 56000: 2.865659
# Average loss at step 58000: 2.740914
# Average loss at step 60000: 2.825445
# Nearest to this: it, which, what, the, another, uscis, guerrero, some,
# Nearest to six: seven, four, five, eight, nine, three, zero, two,
# Nearest to into: through, within, around, from, across, between, over, sexy,
# Nearest to not: never, still, always, actually, now, almost, better, formally,
# Nearest to world: vietnam, binet, deshima, jamil, convergence, season, arterial, albans,
# Nearest to see: include, reduce, matthews, winn, cabins, privately, lg, refer,
# Nearest to or: and, than, rabban, unwilling, though, while, arleigh, mahindra,
# Nearest to s: whose, zel, studs, sharia, dumbarton, isbn, alamos, arcs,
# Nearest to can: could, may, will, must, should, would, might, cannot,
# Nearest to used: designed, written, referred, available, considered, seen, sold, applied,
# Nearest to were: are, have, had, was, including, been, be, poisoning,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to if: when, though, before, then, where, rogues, cannot, although,
# Nearest to on: upon, in, through, within, regarding, at, hellbender, around,
# Nearest to been: become, be, grown, were, jaguars, fallen, was, hypocrisy,
# Nearest to he: she, it, they, there, who, panzer, eventually, soon,
# Average loss at step 62000: 2.840291
# Average loss at step 64000: 2.830208
# Average loss at step 66000: 2.709616
# Average loss at step 68000: 2.730703
# Average loss at step 70000: 2.762144
# Nearest to this: which, it, what, palgrave, the, there, another, hovering,
# Nearest to six: five, eight, four, seven, nine, three, two, zero,
# Nearest to into: through, within, around, from, toward, under, over, towards,
# Nearest to not: never, now, still, always, actually, almost, officially, thickness,
# Nearest to world: vietnam, hominy, binet, convergence, eucharist, progesterone, season, jethro,
# Nearest to see: karenga, references, refer, reduce, matthews, applies, links, but,
# Nearest to or: and, than, formant, remaking, edu, argo, airbases, citing,
# Nearest to s: whose, zel, isbn, aloe, sharia, truss, bromide, larps,
# Nearest to can: must, may, could, will, should, cannot, might, would,
# Nearest to used: seen, sold, found, available, referred, applied, designed, defined,
# Nearest to were: are, have, was, include, including, had, although, is,
# Nearest to nine: eight, seven, five, six, four, zero, three, two,
# Nearest to if: when, though, where, before, although, since, after, today,
# Nearest to on: upon, rotates, through, in, regarding, succeeding, anastasia, nl,
# Nearest to been: become, be, grown, fallen, come, recently, jaguars, already,
# Nearest to he: she, it, they, who, there, we, eventually, then,
# Average loss at step 72000: 2.812717
# Average loss at step 74000: 2.774024
# Average loss at step 76000: 2.652563
# Average loss at step 78000: 2.801954
# Average loss at step 80000: 2.818815
# Nearest to this: which, it, what, uscis, becquerel, antisense, some, palgrave,
# Nearest to six: seven, five, eight, four, three, nine, zero, two,
# Nearest to into: through, within, around, from, under, ditko, across, meade,
# Nearest to not: still, never, actually, almost, always, t, now, generally,
# Nearest to world: vietnam, memorabilia, buddhism, binet, deshima, wtc, u, hominy,
# Nearest to see: include, winn, karenga, cabins, note, matthews, external, mishap,
# Nearest to or: and, than, remaking, weathered, airbases, uncontrollably, und, absalon,
# Nearest to s: whose, dumbarton, isbn, antipsychotic, essendon, larps, kevin, celebrates,
# Nearest to can: could, must, will, may, should, would, might, cannot,
# Nearest to used: sold, referred, found, seen, described, known, applied, designed,
# Nearest to were: are, was, been, have, had, be, those, include,
# Nearest to nine: eight, seven, six, five, zero, three, four, two,
# Nearest to if: when, though, where, before, since, whether, without, excite,
# Nearest to on: upon, in, regarding, at, through, during, under, against,
# Nearest to been: become, be, were, grown, was, come, recently, already,
# Nearest to he: she, it, they, there, who, we, willow, minefields,
# Average loss at step 82000: 2.692566
# Average loss at step 84000: 2.749761
# Average loss at step 86000: 2.731515
# Average loss at step 88000: 2.744036
# Average loss at step 90000: 2.760078
# Nearest to this: which, it, what, some, the, that, palgrave, heron,
# Nearest to six: eight, seven, five, nine, four, three, two, zero,
# Nearest to into: through, from, within, around, across, over, towards, beyond,
# Nearest to not: never, now, actually, t, always, onyx, generally, still,
# Nearest to world: vietnam, memorabilia, eucharist, outages, wtc, internet, convergence, kylix,
# Nearest to see: include, refer, includes, cabins, note, references, matthews, consider,
# Nearest to or: and, than, remaking, while, though, magenta, definiteness, although,
# Nearest to s: isbn, whose, his, zel, dumbarton, celebrates, opal, zhang,
# Nearest to can: could, must, will, should, would, may, cannot, might,
# Nearest to used: applied, referred, sold, known, cited, described, seen, needed,
# Nearest to were: are, was, had, have, those, include, including, persons,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to if: when, though, where, before, since, then, whether, without,
# Nearest to on: upon, through, regarding, anastasia, in, at, within, around,
# Nearest to been: become, grown, be, fallen, hypocrisy, vampyre, recently, come,
# Nearest to he: she, they, it, there, we, who, panzer, alem,
# Average loss at step 92000: 2.658724
# Average loss at step 94000: 2.759931
# Average loss at step 96000: 2.712250
# Average loss at step 98000: 2.690971
# Average loss at step 100000: 2.261757
# Nearest to this: which, it, another, what, palgrave, some, ethelred, achaea,
# Nearest to six: seven, four, five, eight, nine, three, two, zero,
# Nearest to into: through, within, across, beyond, under, around, toward, onto,
# Nearest to not: never, actually, always, occasionally, generally, t, still, now,
# Nearest to world: vietnam, internet, kylix, hindustani, jamil, relinquishing, progesterone, wtc,
# Nearest to see: includes, include, saw, external, karenga, can, note, cabins,
# Nearest to or: and, than, airbases, remaking, though, slavonic, prejudiced, while,
# Nearest to s: whose, his, isbn, dumbarton, loony, american, your, zel,
# Nearest to can: could, must, should, will, cannot, might, would, may,
# Nearest to used: sold, referred, applied, cited, described, introduced, defined, needed,
# Nearest to were: are, was, have, include, had, be, while, lymphedema,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to if: when, though, before, where, excite, without, follows, after,
# Nearest to on: upon, regarding, through, carducci, under, celibate, around, rotates,
# Nearest to been: become, be, grown, fallen, come, was, recently, remained,
# Nearest to he: she, they, it, there, who, we, panzer, ultimately,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
