# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data. Word2vec is an efficient predictive model that directly predicts a word from context (the word' neighbors) in terms of learning small embedding vectors that represent that word. Word2vec has two variations: the skip-gram model predicts the neighbor words from the target words and the continuous bag-of-words model (CBOW) that predicts the word (e.g. 'coffee') from context ('I start each day with a cup of').

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
print(words[:10])
# Out:
# Data size 17005207
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
    
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.271496
# Nearest to is: baptist, detachable, disoriented, corvus, omissions, truk, pleading, maia,
# Nearest to one: seated, masada, barred, restorative, kyrgyz, chromosomal, coil, aruban,
# Nearest to would: preclear, relegation, cameron, hallucinatory, relapse, porvoo, armenia, emitters,
# Nearest to the: repertoire, athelstan, ether, karlheinz, strengthens, frites, villainous, khmelnytsky,
# Nearest to it: rumors, kelly, bombarded, cobol, lautering, gypsys, automobile, hassan,
# Nearest to which: stadt, births, sacramental, monads, facts, yaum, guadalajara, distorts,
# Nearest to world: reactor, tutte, dalai, isomers, undercoat, novo, interlinked, salicylic,
# Nearest to during: flag, goldie, habits, smyrna, cornwallis, interlocking, flaws, fronted,
# Nearest to d: unconcerned, everquest, kernighan, tree, remodeling, dkw, collage, cellini,
# Nearest to than: ki, rocket, engraving, teamwork, attested, cortona, testable, phoenicia,
# Nearest to if: undertones, amerindians, hastings, diverse, ytterbium, infrequently, strengthens, starboard,
# Nearest to used: ilmarinen, certify, bonnie, tawhid, reorganize, darcy, goes, swap,
# Nearest to such: guidebook, orientalis, wonderswan, vagina, nolo, confessed, everyone, bright,
# Nearest to states: discount, retreated, fluctuating, useful, mauritians, dictionnaire, daniels, initially,
# Nearest to also: malfunction, grating, epileptic, jana, wavy, magnifying, weishaupt, shockley,
# Nearest to four: affreightment, depicts, analyzing, illusion, specializations, capitulation, lamorna, plotinus,
# Average loss at step 2000: 4.359089
# Average loss at step 4000: 3.858960
# Average loss at step 6000: 3.786865
# Average loss at step 8000: 3.687106
# Average loss at step 10000: 3.619606
# Nearest to is: was, are, has, be, tbs, baptist, figure, were,
# Nearest to one: two, three, four, six, seven, eight, five, shortness,
# Nearest to would: may, can, wolves, should, will, preclear, porvoo, must,
# Nearest to the: its, his, a, this, their, israeli, gamble, fatou,
# Nearest to it: he, this, there, which, not, they, we, that,
# Nearest to which: this, also, it, yaum, that, who, flavian, encoded,
# Nearest to world: usurp, tutte, iast, reactor, strengthens, fm, righteous, cables,
# Nearest to during: at, in, with, cornwallis, goldie, calvin, interlocking, strongly,
# Nearest to d: unconcerned, everquest, orientational, cellini, b, and, kernighan, oud,
# Nearest to than: rocket, or, redeveloped, ict, information, expert, teamwork, catholic,
# Nearest to if: undertones, hastings, stiller, did, maliki, diverse, let, blaylock,
# Nearest to used: known, arranged, uart, swap, represented, psalms, weaken, hindemith,
# Nearest to such: known, najibullah, purified, everyone, holies, orientalis, vagina, dissent,
# Nearest to states: egyptians, retreated, miraculous, wherever, fluctuating, transfinite, bia, momentarily,
# Nearest to also: which, not, often, holistic, commonly, cornelis, extermination, never,
# Nearest to four: eight, six, three, five, seven, nine, two, zero,
# Average loss at step 12000: 3.602050
# Average loss at step 14000: 3.572136
# Average loss at step 16000: 3.404170
# Average loss at step 18000: 3.458189
# Average loss at step 20000: 3.539588
# Nearest to is: was, has, are, be, octet, maliki, sura, gets,
# Nearest to one: four, two, three, seven, eight, six, five, nine,
# Nearest to would: may, can, will, could, should, must, might, wolves,
# Nearest to the: their, its, this, a, an, his, blames, these,
# Nearest to it: he, there, this, they, which, she, we, not,
# Nearest to which: this, that, who, it, also, these, but, flavian,
# Nearest to world: usurp, earth, city, ink, fm, strengthens, cables, alt,
# Nearest to during: in, at, under, basic, goldie, from, cornwallis, interlocking,
# Nearest to d: b, orientational, cellini, everquest, exorcist, cyrix, unconcerned, oud,
# Nearest to than: or, rocket, expert, mellows, responds, phoenicia, gheorghe, redeveloped,
# Nearest to if: but, did, undertones, let, stiller, when, hastings, maliki,
# Nearest to used: known, represented, uart, hindemith, referred, arranged, swap, weaken,
# Nearest to such: known, najibullah, these, purified, abijah, well, many, vagina,
# Nearest to states: transfinite, fluctuating, retreated, egyptians, wherever, strikeouts, mauritians, peacocks,
# Nearest to also: which, not, never, often, commonly, now, still, it,
# Nearest to four: three, six, eight, seven, five, two, nine, one,
# Average loss at step 22000: 3.500995
# Average loss at step 24000: 3.484974
# Average loss at step 26000: 3.479302
# Average loss at step 28000: 3.477034
# Average loss at step 30000: 3.502441
# Nearest to is: was, has, are, does, be, became, although, homelessness,
# Nearest to one: two, seven, four, eight, three, five, six, nine,
# Nearest to would: may, can, will, could, must, should, might, cannot,
# Nearest to the: their, its, his, a, many, some, tumult, this,
# Nearest to it: he, there, this, they, she, which, we, also,
# Nearest to which: this, that, it, what, but, also, who, flavian,
# Nearest to world: usurp, comanche, righteous, earth, baldrick, chartres, alt, famously,
# Nearest to during: in, after, at, under, akrotiri, parakeet, tommaso, when,
# Nearest to d: b, exorcist, orientational, everquest, hare, stoppage, cellini, commodity,
# Nearest to than: or, rocket, expert, mellows, phoenicia, sombart, gheorghe, discouraged,
# Nearest to if: when, let, did, undertones, however, but, schaff, gave,
# Nearest to used: known, uart, represented, found, referred, written, hindemith, arranged,
# Nearest to such: well, known, some, these, najibullah, abijah, other, musicology,
# Nearest to states: nations, kissinger, transfinite, daniels, peacocks, retreated, grady, subclass,
# Nearest to also: often, never, now, still, which, generally, actually, it,
# Nearest to four: five, three, eight, six, seven, two, nine, zero,
# Average loss at step 32000: 3.503180
# Average loss at step 34000: 3.494215
# Average loss at step 36000: 3.449681
# Average loss at step 38000: 3.296932
# Average loss at step 40000: 3.429973
# Nearest to is: was, has, be, are, if, does, detachable, dismemberment,
# Nearest to one: seven, four, two, six, five, eight, three, nine,
# Nearest to would: will, may, can, could, must, should, might, cannot,
# Nearest to the: a, its, their, this, each, any, his, brilliantly,
# Nearest to it: he, there, they, she, this, we, which, that,
# Nearest to which: that, this, also, what, flavian, it, who, often,
# Nearest to world: usurp, civil, redefining, earth, strengthens, righteous, comanche, subregion,
# Nearest to during: at, in, after, under, tommaso, across, on, through,
# Nearest to d: b, h, exorcist, everquest, hare, die, stoppage, commodity,
# Nearest to than: or, rocket, expert, tal, sombart, much, mellows, clouds,
# Nearest to if: when, let, is, however, undertones, where, windsurfing, schaff,
# Nearest to used: known, found, referred, represented, uart, available, played, considered,
# Nearest to such: well, known, these, including, certain, some, many, abijah,
# Nearest to states: nations, kissinger, dbu, coast, lifeforms, subclass, provisional, mauritians,
# Nearest to also: often, which, still, actually, never, now, generally, sometimes,
# Nearest to four: six, five, seven, three, eight, two, nine, one,
# Average loss at step 42000: 3.440050
# Average loss at step 44000: 3.456624
# Average loss at step 46000: 3.444847
# Average loss at step 48000: 3.352846
# Average loss at step 50000: 3.379845
# Nearest to is: was, has, are, does, contains, gets, cab, provides,
# Nearest to one: two, six, seven, four, eight, three, five, th,
# Nearest to would: will, could, may, can, must, might, should, cannot,
# Nearest to the: its, their, his, this, a, tumult, some, gamble,
# Nearest to it: he, there, this, they, she, now, we, still,
# Nearest to which: that, this, also, often, what, who, flavian, generally,
# Nearest to world: redefining, righteous, civil, opponent, usurp, famously, comanche, tutte,
# Nearest to during: after, in, at, through, tommaso, when, from, akrotiri,
# Nearest to d: b, exorcist, h, die, hare, everquest, curtail, endosymbiotic,
# Nearest to than: or, rocket, expert, discouraged, homeopathy, much, sextans, scenic,
# Nearest to if: when, where, so, though, although, let, however, before,
# Nearest to used: known, referred, found, available, represented, uart, played, expected,
# Nearest to such: these, well, known, many, certain, regarded, najibullah, including,
# Nearest to states: nations, mauritians, government, transfinite, kissinger, kingdom, mechanized, lifeforms,
# Nearest to also: often, now, which, still, never, actually, generally, sometimes,
# Nearest to four: six, three, seven, five, eight, nine, two, zero,
# Average loss at step 52000: 3.433296
# Average loss at step 54000: 3.432836
# Average loss at step 56000: 3.440105
# Average loss at step 58000: 3.397606
# Average loss at step 60000: 3.393309
# Nearest to is: was, are, has, be, provides, contains, gets, does,
# Nearest to one: two, four, six, seven, eight, three, five, nine,
# Nearest to would: will, could, may, can, must, might, should, cannot,
# Nearest to the: its, their, a, this, these, any, some, agate,
# Nearest to it: he, there, this, she, we, which, they, what,
# Nearest to which: that, what, this, it, flavian, who, also, there,
# Nearest to world: chad, civil, comanche, redefining, famously, opponent, righteous, slovenians,
# Nearest to during: after, in, until, before, at, akrotiri, tommaso, through,
# Nearest to d: b, h, exorcist, hare, boone, japonic, r, orie,
# Nearest to than: or, and, rocket, much, expert, but, sombart, mellows,
# Nearest to if: when, where, though, since, before, although, so, while,
# Nearest to used: referred, known, available, found, represented, written, considered, played,
# Nearest to such: known, these, well, certain, many, regarded, having, including,
# Nearest to states: nations, kingdom, bangladesh, countries, government, citizens, lifeforms, urine,
# Nearest to also: now, still, often, never, actually, generally, usually, sometimes,
# Nearest to four: six, five, seven, three, eight, nine, two, one,
# Average loss at step 62000: 3.244541
# Average loss at step 64000: 3.252774
# Average loss at step 66000: 3.402381
# Average loss at step 68000: 3.392856
# Average loss at step 70000: 3.357326
# Nearest to is: was, has, be, are, becomes, contains, seems, does,
# Nearest to one: two, six, seven, four, eight, five, three, nine,
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to the: its, their, a, this, any, each, these, some,
# Nearest to it: he, there, she, this, they, we, freiburg, still,
# Nearest to which: that, this, what, flavian, also, but, actually, who,
# Nearest to world: redefining, chad, scene, commission, naples, ink, slovenians, comanche,
# Nearest to during: after, in, until, before, through, tommaso, since, from,
# Nearest to d: b, h, exorcist, hare, f, g, paranoid, scabbard,
# Nearest to than: rocket, or, mellows, discouraged, expert, reasonably, no, responds,
# Nearest to if: when, though, where, although, however, before, since, while,
# Nearest to used: referred, known, found, available, written, represented, played, designed,
# Nearest to such: these, known, well, certain, many, regarded, including, having,
# Nearest to states: nations, kingdom, countries, bangladesh, state, missiles, government, urine,
# Nearest to also: now, still, often, actually, which, never, generally, sometimes,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Average loss at step 72000: 3.371036
# Average loss at step 74000: 3.348667
# Average loss at step 76000: 3.311443
# Average loss at step 78000: 3.348709
# Average loss at step 80000: 3.380569
# Nearest to is: was, has, are, be, became, provides, zola, zarah,
# Nearest to one: seven, six, two, eight, three, four, five, nine,
# Nearest to would: will, could, might, may, can, must, should, cannot,
# Nearest to the: its, their, a, paucity, his, another, this, brilliantly,
# Nearest to it: he, there, she, this, we, they, now, genomic,
# Nearest to which: that, this, what, also, actually, who, flavian, but,
# Nearest to world: redefining, commission, chad, slovenians, mandolins, chartres, scene, righteous,
# Nearest to during: after, in, when, before, until, through, while, including,
# Nearest to d: b, h, exorcist, everquest, f, hare, endosymbiotic, scabbard,
# Nearest to than: or, but, rocket, much, reasonably, nielsen, megatokyo, somewhat,
# Nearest to if: when, though, since, before, because, where, although, unless,
# Nearest to used: available, known, found, referred, represented, written, seen, designed,
# Nearest to such: well, certain, these, regarded, known, including, follows, described,
# Nearest to states: nations, kingdom, countries, government, bangladesh, state, urine, lifeforms,
# Nearest to also: now, often, actually, still, which, commonly, never, generally,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Average loss at step 82000: 3.408024
# Average loss at step 84000: 3.410156
# Average loss at step 86000: 3.387927
# Average loss at step 88000: 3.355848
# Average loss at step 90000: 3.363972
# Nearest to is: was, has, are, becomes, although, be, requires, does,
# Nearest to one: seven, two, four, eight, six, three, five, th,
# Nearest to would: will, could, might, may, can, must, should, cannot,
# Nearest to the: their, its, his, this, any, compl, a, bowled,
# Nearest to it: he, she, there, this, they, we, registrar, eulogy,
# Nearest to which: that, this, also, what, actually, flavian, personhood, but,
# Nearest to world: redefining, ink, righteous, commission, competitions, mandolins, chad, earth,
# Nearest to during: after, before, until, through, in, when, at, while,
# Nearest to d: b, scabbard, f, h, exorcist, hare, kilometre, everquest,
# Nearest to than: or, reasonably, rocket, operettas, nielsen, no, much, mvd,
# Nearest to if: when, though, where, since, before, so, although, however,
# Nearest to used: available, known, referred, found, designed, seen, represented, called,
# Nearest to such: known, certain, well, regarded, these, including, special, many,
# Nearest to states: nations, kingdom, state, government, countries, urine, bangladesh, mauritians,
# Nearest to also: actually, now, often, which, still, generally, commonly, usually,
# Nearest to four: five, seven, six, three, eight, two, nine, one,
# Average loss at step 92000: 3.397281
# Average loss at step 94000: 3.251435
# Average loss at step 96000: 3.358212
# Average loss at step 98000: 3.238260
# Average loss at step 100000: 3.358357
# Nearest to is: was, has, be, gets, became, seems, are, refers,
# Nearest to one: two, four, seven, three, six, eight, five, pmid,
# Nearest to would: will, could, might, can, may, should, must, cannot,
# Nearest to the: his, its, your, our, their, this, brilliantly, azhar,
# Nearest to it: he, she, this, there, they, what, still, we,
# Nearest to which: that, this, what, also, actually, usually, frequently, but,
# Nearest to world: redefining, mandolins, competitions, naples, returning, fined, ink, celebrating,
# Nearest to during: in, after, until, before, when, through, within, throughout,
# Nearest to d: b, h, curtail, exorcist, rbi, f, scabbard, bucket,
# Nearest to than: or, operettas, much, reasonably, discouraged, mayr, rocket, curiously,
# Nearest to if: when, though, where, so, since, although, hence, before,
# Nearest to used: available, designed, represented, referred, found, written, seen, known,
# Nearest to such: well, known, regarded, certain, many, these, including, follows,
# Nearest to states: nations, kingdom, state, bangladesh, us, government, countries, archaeologist,
# Nearest to also: actually, now, still, often, sometimes, which, generally, never,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# CBOW model
# predict a word from the sum of all the word vectors in its context
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# batch : [['anarchism', 'as'], ['originated', 'a'], ['as', term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first']]
# labels: ['originated', 'as', 'a', 'term', 'of', 'abuse']

words = read_data(filename)
print('Data size %d' % len(words))
print(words[:10])

# vocabulary_size = 50000

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Data size 17005207
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
from itertools import compress

data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  # span = 3
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  # batch_size = 8
  # num_skips = 2
  # skip_window = 1
  # data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
  # batch: [['anarchism', 'as'], ['originated','a'],['as','term'], ['a','of'], ['term','abuse'],['of','first']]
  # labels: ['originated','as','a','term','of','abuse']

  # num_skips = 4
  # skip_window = 2
  # batch: [['anarchism', 'originated','a','term'], ['originated','as', 'term', 'of']]
  # labels: ['as','a', 'term', 'of']

  for i in range(batch_size ):
    mask = [1] * span
    target = skip_window  # target label at the center of the buffer
    mask[target] = 0
    labels[i,0] = buffer[target]
    batch[i,:] = list(compress(buffer, mask))
    buffer.append(data[data_index])  
#     print('buffer  :', [reverse_dictionary[bi] for bi in buffer])
    data_index = (data_index + 1) % len(data)
#     print("batch data shape: {}".format(batch.shape))
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8-2*skip_window, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(num_skips * (8-2*skip_window) )])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8-2*skip_window)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term', 'originated', 'as', 'term', 'of', 'as', 'a', 'of', 'abuse', 'a', 'term', 'abuse', 'first']
#     labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# Train a CBOW model.

# %%
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

batch_size = 128 - 2*skip_window
embedding_size = 128 - 2*skip_window # Dimension of the embedding vector.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
    
  print("train data shape: {}".format(train_dataset))

  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
    
  embed = tf.zeros([batch_size, embedding_size])
  for i in range(num_skips):
      embed += tf.nn.embedding_lookup(embeddings, train_dataset[:,i])

# Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# train data shape: Tensor("Placeholder:0", shape=(126, 2), dtype=int32, device=/device:CPU:0)

# %%
num_steps = 100001
# num_steps = 1
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):    
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window) 
    
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.726739
# Nearest to of: tishri, dvorak, meteorite, additivity, hangar, balkan, antigen, accentual,
# Nearest to his: gruesome, rorty, holism, they, queueing, dilemma, prerequisite, changing,
# Nearest to however: times, incumbent, multics, successfully, publicised, copyright, broome, hedonist,
# Nearest to see: algernon, embed, bahr, elphinstone, refrigerator, rammed, rader, novi,
# Nearest to he: legislate, concerns, initiation, boniface, silhouette, pursue, usurp, afar,
# Nearest to four: reidel, simcity, gaines, liao, hipper, reine, hurst, argyle,
# Nearest to called: kenilworth, creditors, triumphs, hoaxes, smell, spaniard, blistering, noradrenaline,
# Nearest to is: winnings, iib, southern, laptop, tortures, agrippa, burlesque, hoe,
# Nearest to nine: covariant, overtones, misdemeanor, tulip, eiffel, alvarez, weaver, oratory,
# Nearest to with: preoccupation, formalised, shotgun, fridtjof, cochran, vampire, flaps, avl,
# Nearest to an: cry, phrase, government, aisle, volatile, partly, swallowing, partnership,
# Nearest to only: pmod, catholicism, roma, nuh, brothers, historic, anabaptism, hempstead,
# Nearest to or: migraine, prerecorded, tools, answered, vanishes, maidens, flank, guises,
# Nearest to time: fountains, aleut, marge, gyro, macquarie, hubei, alhazred, uncertain,
# Nearest to it: ruins, navis, resonator, hamish, krueger, baptist, normally, dripping,
# Nearest to known: nullify, breatharian, pds, carolyn, undernet, apteryx, abalone, timecode,
# Average loss at step 2000: 4.031772
# Average loss at step 4000: 3.543099
# Average loss at step 6000: 3.402533
# Average loss at step 8000: 3.356671
# Average loss at step 10000: 3.284408
# Nearest to of: churning, paraguay, for, bazille, rarity, mountbatten, rationalists, carousel,
# Nearest to his: their, its, her, the, s, oghuz, allocation, wearable,
# Nearest to however: hammerhead, successfully, so, but, cytokines, hilberg, broome, times,
# Nearest to see: refraining, fumimaro, abdullah, exemption, bahr, visionaries, quitting, liberator,
# Nearest to he: it, they, she, who, i, there, transjordan, never,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to called: spaniard, chaim, smell, fiddlers, and, obligation, accentuate, tc,
# Nearest to is: was, are, has, be, were, juncture, tou, regained,
# Nearest to nine: seven, eight, six, four, five, zero, three, two,
# Nearest to with: between, shunting, preoccupation, for, in, unorthodox, flashback, journals,
# Nearest to an: inevitably, israelis, diacritical, landis, nada, freedmen, proverbs, bartolom,
# Nearest to only: airplane, desalination, ignorance, gigi, scouting, gbc, courant, tay,
# Nearest to or: and, than, corroborated, prattica, nourishment, compressing, wilhelm, migraine,
# Nearest to time: vet, deported, aleut, marge, macquarie, wiped, studios, leapt,
# Nearest to it: he, she, there, they, still, which, podcast, usually,
# Nearest to known: well, used, boyz, tyne, detention, burglary, abalone, entropy,
# Average loss at step 12000: 3.132251
# Average loss at step 14000: 3.184014
# Average loss at step 16000: 3.174578
# Average loss at step 18000: 3.054230
# Average loss at step 20000: 3.113794
# Nearest to of: during, in, carp, churning, residue, marek, aran, for,
# Nearest to his: their, her, its, my, the, whose, your, humphrey,
# Nearest to however: but, although, while, that, though, when, if, so,
# Nearest to see: quitting, refraining, include, undivided, bargaining, dylan, baloch, find,
# Nearest to he: she, it, they, who, there, i, we, deirdre,
# Nearest to four: eight, five, six, seven, nine, three, two, zero,
# Nearest to called: named, used, musketeers, propagated, fixation, organometallic, dodge, settler,
# Nearest to is: was, has, are, became, becomes, telford, inherits, means,
# Nearest to nine: eight, six, four, seven, five, zero, three, two,
# Nearest to with: between, by, prophase, preoccupation, against, jimmie, into, padre,
# Nearest to an: clitoridectomy, freedmen, inevitably, israelis, diacritical, landis, asteraceae, portal,
# Nearest to only: first, winona, gbc, always, oxidative, honduras, excludes, airplane,
# Nearest to or: and, than, migraine, paperback, rhee, rabies, legions, possessors,
# Nearest to time: vet, studios, soga, chs, way, primacy, affirmed, darussalam,
# Nearest to it: he, she, this, there, atwood, drc, luster, which,
# Nearest to known: well, used, such, recognized, notable, detention, goose, redesignated,
# Average loss at step 22000: 3.082631
# Average loss at step 24000: 3.027879
# Average loss at step 26000: 2.889244
# Average loss at step 28000: 3.000644
# Average loss at step 30000: 3.005958
# Nearest to of: including, closest, churning, during, bazille, in, paraguay, agnosticism,
# Nearest to his: their, her, its, my, the, your, our, s,
# Nearest to however: but, although, though, while, that, when, broome, should,
# Nearest to see: undivided, include, ou, wallabies, bean, dylan, but, refraining,
# Nearest to he: she, it, they, there, who, subsequently, successfully, deirdre,
# Nearest to four: five, six, seven, eight, three, nine, zero, two,
# Nearest to called: named, used, known, fixation, organometallic, calorimeter, yusupov, magazines,
# Nearest to is: was, has, becomes, are, became, includes, contains, midway,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to with: between, jimmie, by, unorthodox, prophase, toland, during, shunting,
# Nearest to an: freedmen, clitoridectomy, diacritical, israelis, wizard, inevitably, swallowing, loads,
# Nearest to only: always, airplane, oxidative, pores, recipients, first, mwi, exactly,
# Nearest to or: and, than, paperback, but, loach, krush, rodr, smallholders,
# Nearest to time: studios, vet, year, primacy, way, period, affirmed, centuries,
# Nearest to it: he, she, there, this, still, which, they, often,
# Nearest to known: used, such, recognized, well, called, defined, redesignated, seen,
# Average loss at step 32000: 2.953466
# Average loss at step 34000: 3.003905
# Average loss at step 36000: 3.010279
# Average loss at step 38000: 2.955758
# Average loss at step 40000: 2.967375
# Nearest to of: bazille, for, including, anticonvulsant, during, shaitan, dde, carp,
# Nearest to his: her, their, its, my, your, the, whose, our,
# Nearest to however: but, although, though, while, that, whistle, involved, cases,
# Nearest to see: wallabies, include, pretended, bean, but, ka, known, palos,
# Nearest to he: she, it, they, there, we, who, originally, never,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Nearest to called: named, known, used, organometallic, designed, fixation, bohdan, calorimeter,
# Nearest to is: was, has, are, be, becomes, contains, michell, seems,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to with: between, preoccupation, shunting, stakes, in, prophase, publishes, neoclassicism,
# Nearest to an: inevitably, nada, freedmen, diacritical, clitoridectomy, betsy, loads, countering,
# Nearest to only: still, exactly, recipients, airplane, just, immediately, unrepentant, then,
# Nearest to or: and, than, migraine, paperback, mesoplodon, though, simultaneous, confessing,
# Nearest to time: period, vet, affirmed, chs, primacy, sequence, studios, soga,
# Nearest to it: he, she, there, this, they, chickens, jacquard, hahnemann,
# Nearest to known: used, such, called, defined, described, recognized, considered, responsible,
# Average loss at step 42000: 2.876301
# Average loss at step 44000: 2.873683
# Average loss at step 46000: 2.911297
# Average loss at step 48000: 2.902730
# Average loss at step 50000: 2.770581
# Nearest to of: including, in, rth, churning, exxon, lillehammer, bazille, marek,
# Nearest to his: her, their, my, its, your, our, whose, the,
# Nearest to however: but, although, that, though, which, nutcracker, barbosa, mixes,
# Nearest to see: include, wallabies, bean, undivided, pretended, nola, schleicher, chera,
# Nearest to he: she, it, they, there, who, originally, we, swain,
# Nearest to four: six, five, seven, eight, three, nine, zero, two,
# Nearest to called: named, known, referred, fixation, used, designed, organometallic, considered,
# Nearest to is: was, has, becomes, are, became, represents, michell, ganglion,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to with: between, preoccupation, positrons, shunting, using, toland, jimmie, molotov,
# Nearest to an: inevitably, clitoridectomy, nada, israelis, rations, freedmen, asgard, loads,
# Nearest to only: still, immediately, solicited, always, just, recipients, exactly, mwi,
# Nearest to or: and, than, corroborated, migraine, mesoplodon, martens, christina, paperback,
# Nearest to time: period, studios, chs, vet, hemorrhage, darussalam, primacy, affirmed,
# Nearest to it: he, she, there, this, they, atwood, now, today,
# Nearest to known: used, such, defined, considered, recognized, called, described, responsible,
# Average loss at step 52000: 2.853817
# Average loss at step 54000: 2.885708
# Average loss at step 56000: 2.844061
# Average loss at step 58000: 2.744774
# Average loss at step 60000: 2.770763
# Nearest to of: including, in, despite, caveats, carp, spindle, against, although,
# Nearest to his: her, their, its, my, your, our, whose, the,
# Nearest to however: although, but, though, while, that, nutcracker, especially, until,
# Nearest to see: include, pretended, schleicher, nola, but, wallabies, enable, choose,
# Nearest to he: she, it, they, there, who, we, i, originally,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to called: named, known, designed, referred, fixation, considered, nell, lefty,
# Nearest to is: was, has, are, becomes, does, be, seems, became,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to with: between, including, preoccupation, jimmie, by, toppling, punic, in,
# Nearest to an: betsy, another, israelis, haile, inevitably, asgard, montju, assr,
# Nearest to only: always, still, exactly, mwi, densities, yet, airplane, normally,
# Nearest to or: and, than, wherein, migraine, vir, rhee, paperback, portfolios,
# Nearest to time: period, day, ssbn, year, chs, dyskinesia, studios, perry,
# Nearest to it: she, he, there, they, this, itself, now, often,
# Nearest to known: used, defined, such, recognized, written, described, considered, called,
# Average loss at step 62000: 2.815761
# Average loss at step 64000: 2.787441
# Average loss at step 66000: 2.799314
# Average loss at step 68000: 2.680825
# Average loss at step 70000: 2.829934
# Nearest to of: in, bazille, during, carp, additivity, caveats, stellar, churning,
# Nearest to his: her, their, its, my, your, our, whose, minigun,
# Nearest to however: although, but, though, that, while, until, nutcracker, where,
# Nearest to see: include, but, pretended, external, includes, wallabies, according, eui,
# Nearest to he: she, it, they, we, who, there, originally, never,
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Nearest to called: named, referred, designed, used, lefty, known, considered, fixation,
# Nearest to is: was, has, becomes, are, contains, be, does, michell,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to with: between, preoccupation, by, in, involving, within, using, unorthodox,
# Nearest to an: inevitably, clitoridectomy, another, diacritical, montju, nada, shermer, freedmen,
# Nearest to only: still, always, yet, exactly, debussy, illuminate, tacit, actually,
# Nearest to or: and, rodr, than, migraine, funicular, disastrously, rhee, comparably,
# Nearest to time: day, primacy, domestication, vet, grounds, dyskinesia, swollen, studios,
# Nearest to it: she, he, there, this, they, itself, today, quasar,
# Nearest to known: used, defined, such, regarded, considered, described, recognized, notable,
# Average loss at step 72000: 2.844540
# Average loss at step 74000: 2.738193
# Average loss at step 76000: 2.743559
# Average loss at step 78000: 2.738202
# Average loss at step 80000: 2.781106
# Nearest to of: bazille, including, despite, churning, posthumous, antigen, bentheim, rarity,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to however: but, although, though, until, while, since, nutcracker, etc,
# Nearest to see: include, wallabies, pretended, but, amit, external, includes, nola,
# Nearest to he: she, it, they, there, we, originally, swain, directv,
# Nearest to four: five, six, seven, eight, nine, three, zero, two,
# Nearest to called: named, referred, known, used, considered, responsible, haakon, described,
# Nearest to is: was, becomes, has, are, contains, remains, does, be,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to with: between, preoccupation, using, watered, jimmie, shunting, drier, prophase,
# Nearest to an: inevitably, israelis, another, diacritical, nada, montju, freedmen, betsy,
# Nearest to only: either, always, still, tacit, yet, normally, no, mwi,
# Nearest to or: and, than, intellivision, mesoplodon, lemon, thar, sterile, sane,
# Nearest to time: day, kind, domestication, period, dyskinesia, chs, studios, vet,
# Nearest to it: he, she, there, this, itself, they, today, nicephorus,
# Nearest to known: used, defined, such, recognized, regarded, described, responsible, called,
# Average loss at step 82000: 2.774733
# Average loss at step 84000: 2.671660
# Average loss at step 86000: 2.773497
# Average loss at step 88000: 2.725515
# Average loss at step 90000: 2.709155
# Nearest to of: for, although, bazille, in, and, including, despite, socializing,
# Nearest to his: their, her, your, my, its, our, the, whose,
# Nearest to however: although, but, though, while, that, especially, until, affirming,
# Nearest to see: include, pretended, wallabies, external, enable, tter, called, tagus,
# Nearest to he: she, it, they, there, i, we, ultimately, fournier,
# Nearest to four: five, six, three, seven, eight, zero, nine, two,
# Nearest to called: named, known, referred, used, designed, see, kris, nell,
# Nearest to is: was, becomes, became, remains, has, are, contains, seems,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to with: between, preoccupation, involving, shunting, girlfriend, prophase, erg, by,
# Nearest to an: clitoridectomy, inevitably, bartolom, israelis, asgard, diacritical, landis, nada,
# Nearest to only: either, receiving, necessarily, just, until, always, yet, necessary,
# Nearest to or: and, than, mesoplodon, reproducing, coogan, but, though, newt,
# Nearest to time: kind, precision, primacy, distances, day, week, period, month,
# Nearest to it: he, she, there, they, this, itself, today, atwood,
# Nearest to known: used, such, regarded, recognized, defined, called, described, responsible,
# Average loss at step 92000: 2.294146
# Average loss at step 94000: 2.429972
# Average loss at step 96000: 2.635490
# Average loss at step 98000: 2.645173
# Average loss at step 100000: 2.739071
# Nearest to of: discriminatory, additivity, shaitan, despite, rationalists, carp, tley, anticonvulsant,
# Nearest to his: her, their, your, my, its, whose, our, wearable,
# Nearest to however: although, but, though, while, that, especially, when, etc,
# Nearest to see: include, enable, includes, according, pretended, references, tagus, define,
# Nearest to he: she, it, they, there, we, eventually, who, tapioca,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to called: named, referred, designed, used, responsible, known, dedicated, nell,
# Nearest to is: was, remains, becomes, has, are, contains, represents, michell,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to with: between, preoccupation, involving, jimmie, shunting, prophase, by, using,
# Nearest to an: inevitably, diacritical, nada, another, asgard, saladin, muller, assr,
# Nearest to only: either, receiving, just, yet, still, necessarily, normally, always,
# Nearest to or: and, than, though, mesoplodon, christina, intellivision, migraine, vs,
# Nearest to time: kind, period, month, week, day, manchukuo, precision, primacy,
# Nearest to it: she, he, there, this, itself, they, typically, still,
# Nearest to known: used, regarded, recognized, such, notable, defined, available, famous,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
